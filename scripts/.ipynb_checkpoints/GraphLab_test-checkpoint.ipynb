# %%
import sys
sys.path.insert(0, '../YTCollab/src')

import extract_data
import scoreboard

# %%
df = pd.read_csv('../YTCollab/data/YTGaming.csv', encoding='utf-8').drop('Unnamed: 0', axis=1)

# %%
y = extract_data.get_specific_channel('UCCbfB3cQtkEAiKfdRQnfQvw')
# Out:
# 1.53576588631
# ../YTCollab/src/extract_data.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_new[topic][i] = count

# %%
score = scoreboard.Scoreboard()
score.fit(df, y)

# %%
score.most_similar()
# Out:
# [u'King Gothalion',
#  u'Razzbowski',
#  u'FinalBoss.tv',
#  u'TheWaffleGalaxy',
#  u'VGameOSTs',
#  u'ShoddyCast',
#  u'Alzu Gaming',
#  u'TotalBiscuit Starcraft and Axiom eSports',
#  u'arCtiCvBi',
#  u'yamimash']

# %%
y = extract_data.get_specific_channel('UCcx01rLXJ4dCtXqW3kPmBzg')
score.find_similar(y)
score.most_similar()
# Out:
# 3.51570415497
# [u"Gamer's Little Playground",
#  u'Sips',
#  u'SplatterCatGaming',
#  u'Boss Fight Database',
#  u'DidYouKnowGaming?',
#  u'SLEEPCYCLES',
#  u'Lobos Jr',
#  u'bisnap',
#  u'RaedwulfGamer',
#  u'GameGrumps']

# %%
import graphlab
from graphlab import SFrame

# %%
df[df['title'] == 'Jesse Cox'][score.match_col]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4364d012dede> in <module>()
# ----> 1 df[df['title'] == 'Jesse Cox'][score.match_col]
#
# NameError: name 'score' is not defined

# %%
df, y = extract_data.match_topics(df, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c8f5ae7eb176> in <module>()
# ----> 1 df, y = extract_data.match_topics(df, y)
#
# /home/alex/Galvanize_Capstone/YouTube_Collab_Recommender/YTCollab/src/extract_data.pyc in match_topics(X, y)
#     254     for topic in X_new.columns[5:]:
#     255         y_new[topic] = 0
# --> 256     for row in y_new['topics']:
#     257         for i, topic in enumerate(row):
#     258             try:
#
# /home/alex/anaconda2/lib/python2.7/site-packages/pandas-0.17.1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# ...

# %%
y[score.match_col]
# Out:
#    /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 0         2  868876    3327         5         1          5           3
#
#    /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  /m/025zzc  \
# 0           1         1         1    ...              1        1          3
#
#    /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  /m/095bb  /m/06nh1
# 0          1           1         1        2          1         2         1
#
# [1 rows x 31 columns]

# %%
score.df[score.df['title'] == 'Jesse Cox'][score.match_col]
# Out:
#       /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 1403         2  868876    3327         5         1          5           3
#
#       /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  \
# 1403           1         1         1    ...              1        1
#
#       /m/025zzc  /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  \
# 1403          3          1           1         1        2          1
#
#       /m/095bb  /m/06nh1
# 1403         2         1
#
# [1 rows x 31 columns]

# %%
score.df[score.df['title'] == 'Jesse Cox'][score.match_col]
# Out:
#       /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 1403         2  868876    3327         5         1          5           3
#
#       /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  \
# 1403           1         1         1    ...              1        1
#
#       /m/025zzc  /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  \
# 1403          3          1           1         1        2          1
#
#       /m/095bb  /m/06nh1
# 1403         2         1
#
# [1 rows x 31 columns]

# %%
score.df[score.df['title'] == 'Genna Bain'][score.match_col]
# Out:
#       /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 1392         0  140974     119         1         0          4           1
#
#       /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  \
# 1392           1         1         0    ...              0        1
#
#       /m/025zzc  /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  \
# 1392          3          1           0         0        0          0
#
#       /m/095bb  /m/06nh1
# 1392         0         0
#
# [1 rows x 31 columns]

# %%
score.df[score.df['title'] == 'iancoullahan1'][score.match_col]
# Out:
#       /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 1352         1  196103     600         0         1          1           1
#
#       /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  \
# 1352           0         0         0    ...              1        0
#
#       /m/025zzc  /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  \
# 1352          1          1           0         0        0          0
#
#       /m/095bb  /m/06nh1
# 1352         0         0
#
# [1 rows x 31 columns]

# %%
score.df_ranked_idx[0]
# Out:
# 316

# %%
score.df[316:317][score.match_col]
# Out:
#      /m/0g65_    subs  videos  /m/01mw1  /m/03glg  /m/0bzvm2  /m/03bt1gh  \
# 316         4  379632    1920         6         0          5           6
#
#      /m/03hf_rm  /m/0k80c  /m/0f7yn    ...     /m/0403l3g  /m/0jbk  /m/025zzc  \
# 316           0         0         0    ...              0        0          0
#
#      /m/019_rr  /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  /m/095bb  /m/06nh1
# 316          0           0         0        0          0         0         0
#
# [1 rows x 31 columns]

# %%
score.df_ranked_idx
# Out:
# array([1351,  314,  145, ..., 1017, 1239, 1250])

# %%
df.ix[1351]
# Out:
# title          Genna Bain
# country                US
# subs               141002
# videos                119
# views            15434493
# /m/02hrh1q              0
# /m/07vqnc               0
# /m/0gyv1hg              0
# /m/02n4hz               0
# /m/03d3jcv              0
# /m/025rw19              0
# /m/03dj64               0
# /m/02gzp                0
# /m/03hdcz               0
# /m/051hj                0
# /m/06bx0m               0
# /m/01yg9g               0
# /m/0g27s9               0
# /m/0h5x4j3              0
# /m/0hpqgx2              0
# /m/083sl                0
# /m/016qgq               0
# /m/010x7qgm             0
# /m/0134m0m8             0
# /m/044yrn               0
# /m/02mktm               0
# /m/06w35h8              0
# /m/0k3m1lg              0
# /m/04yc1jr              0
# /m/03xnmz6              0
#                   ...
# /m/01j2ln               0
# /m/0cc56                0
# /m/07608d               0
# /m/047lzp               0
# ...

# %%
score.df.ix[1351]
# Out:
# title          iancoullahan1
# country                  n/a
# subs                  196103
# videos                   600
# views               82922898
# /m/02hrh1q                 0
# /m/07vqnc                  0
# /m/0gyv1hg                 0
# /m/02n4hz                  0
# /m/03d3jcv                 0
# /m/025rw19                 0
# /m/03dj64                  0
# /m/02gzp                   0
# /m/03hdcz                  0
# /m/051hj                   0
# /m/06bx0m                  0
# /m/01yg9g                  0
# /m/0g27s9                  0
# /m/0h5x4j3                 0
# /m/0hpqgx2                 0
# /m/083sl                   0
# /m/016qgq                  0
# /m/010x7qgm                0
# /m/0134m0m8                0
# /m/044yrn                  0
# /m/02mktm                  0
# /m/06w35h8                 0
# /m/0k3m1lg                 0
# /m/04yc1jr                 0
# /m/03xnmz6                 0
#                    ...
# /m/01j2ln                  0
# ...

# %%
y.head()
# Out:
#        title country    subs  videos      views  /m/0g65_  /m/01mw1  /m/03glg  \
# 0  Jesse Cox      US  868862    3327  365482749         2         5         1
#
#    /m/0bzvm2  /m/03bt1gh    ...     /m/0403l3g  /m/0jbk  /m/025zzc  /m/019_rr  \
# 0          5           3    ...              1        1          3          1
#
#    /m/0cp0zz4  /m/0215n  /m/0hcr  /m/0184bl  /m/095bb  /m/06nh1
# 0           1         1        2          1         2         1
#
# [1 rows x 33 columns]

# %%
score.df['title'][[5, 1351]]
# Out:
# 5       theRadBrad
# 1351       Smeepbb
# Name: title, dtype: object

# %%
df['title'][1351]
# Out:
# u'Genna Bain'

# %%
score.scores
# Out:
# array([[ 0.99999235,  0.99999894,  0.99999836, ...,  0.99973739,
#          0.99999476,  0.99923909]])

# %%
np.argsort(score.scores)
# Out:
# array([[1250, 1239, 1017, ...,  145,  314, 1351]])

# %%
score.df.columns
# Out:
# Index([u'title', u'country', u'subs', u'videos', u'views', u'/m/02hrh1q',
#        u'/m/07vqnc', u'/m/0gyv1hg', u'/m/02n4hz', u'/m/03d3jcv',
#        ...
#        u'/m/0248b', u'/m/06l9b', u'/m/026dz5f', u'/m/07f_7h', u'/m/01ct6',
#        u'/m/079m5l', u'/m/0174k2', u'/m/043mm3', u'/m/05v954', u'/m/02zw41'],
#       dtype='object', length=7192)

# %%
pd.DataFrame(y, columns=df.columns).fillna(0)
# Out:
#       title country  subs  videos  views  /m/02hrh1q  /m/07vqnc  /m/0gyv1hg  \
# 0  LichWick      US    63     185   4933           0          0           0
#
#    /m/02n4hz  /m/03d3jcv    ...      /m/0248b  /m/06l9b  /m/026dz5f  \
# 0          0           0    ...             0         0           0
#
#    /m/07f_7h  /m/01ct6  /m/079m5l  /m/0174k2  /m/043mm3  /m/05v954  /m/02zw41
# 0          0         0          0          0          0          0          0
#
# [1 rows x 7158 columns]

# %%
score.most_similar()
# Out:
# [u'FinalBoss.tv',
#  u'YOGSCAST Rythian',
#  u'LifesAGlitchTV',
#  u'JinBop',
#  u'Olizandri',
#  u'TotalBiscuit Starcraft and Axiom eSports',
#  u'TheWaffleGalaxy',
#  u'SuperJeenius',
#  u'TradeChat',
#  u'GOM eXP Official']

# %%
np.sum(score.df['title'] == score.y['title'][0])
# Out:
# 1

# %%
score.df.shape
# Out:
# (1405, 7192)

# %%
score.find_similar(y)

# %%
score.df[score.df['title'] == 'Jesse Cox']
# Out:
#           title country    subs  videos      views  /m/02hrh1q  /m/07vqnc  \
# 1403  Jesse Cox      US  868671    3326  365328932           0          0
#
#       /m/0gyv1hg  /m/02n4hz  /m/03d3jcv    ...      /m/0248b  /m/06l9b  \
# 1403           0          0           0    ...             0         0
#
#       /m/026dz5f  /m/07f_7h  /m/01ct6  /m/079m5l  /m/0174k2  /m/043mm3  \
# 1403           0          0         0          0          0          0
#
#       /m/05v954  /m/02zw41
# 1403          0          0
#
# [1 rows x 7192 columns]

# %%
score.df_ranked_idx
# Out:
# array([1351,  314,  145, ..., 1017, 1239, 1250])

# %%
df['title'][1351]
# Out:
# u'Genna Bain'

# %%
score.df[1403:1404]
# Out:
#           title country    subs  videos      views  /m/02hrh1q  /m/07vqnc  \
# 1403  Jesse Cox      US  868684    3326  365328932           0          0
#
#       /m/0gyv1hg  /m/02n4hz  /m/03d3jcv    ...      /m/0248b  /m/06l9b  \
# 1403           0          0           0    ...             0         0
#
#       /m/026dz5f  /m/07f_7h  /m/01ct6  /m/079m5l  /m/0174k2  /m/043mm3  \
# 1403           0          0         0          0          0          0
#
#       /m/05v954  /m/02zw41
# 1403          0          0
#
# [1 rows x 7192 columns]

# %%
score.scores[0][1351]
# Out:
# 0.9999999999146657

# %%
score.df['title'][144]
# Out:
# u'outsidexbox'

# %%
df = pd.read_csv('../YTCollab/data/YTGaming_base.csv', encoding='utf-8')
df = df.drop('Unnamed: 0', axis=1)
sdf = SFrame(df)

# %%
sdf
# Out:
# Columns:
# 	title	str
# 	country	str
# 	subs	int
# 	videos	int
# 	views	int
# 	/m/02hrh1q	int
# 	/m/07vqnc	int
# 	/m/0gyv1hg	int
# 	/m/02n4hz	int
# 	/m/03d3jcv	int
# 	/m/025rw19	int
# 	/m/03dj64	int
# 	/m/02gzp	int
# 	/m/03hdcz	int
# 	/m/051hj	int
# 	/m/06bx0m	int
# 	/m/01yg9g	int
# 	/m/0g27s9	int
# 	/m/0h5x4j3	int
# 	/m/0hpqgx2	int
# 	/m/083sl	int
# 	/m/016qgq	int
# 	/m/010x7qgm	int
# 	/m/0134m0m8	int
# 	/m/044yrn	int
# 	/m/02mktm	int
# 	/m/06w35h8	int
# 	/m/0k3m1lg	int
# 	/m/04yc1jr	int
# 	/m/03xnmz6	int
# 	/m/0kyshy1	int
# 	/m/02vyjtr	int
# 	/m/05g49	int
# 	/m/095k7	int
# 	/m/0542r6	int
# 	/m/059_c	int
# 	/m/02v_j9n	int
# 	/m/0m5hdz	int
# 	/m/03s4kf	int
# 	/m/028kb	int
# 	/m/0y639q6	int
# 	/m/04stgv	int
# 	/m/048xk0	int
# 	/m/06qln	int
# 	/m/055w7h	int
# 	/m/011l78	int
# 	/m/0dlyx	int
# 	/m/02lx2r	int
# 	/m/0134jnqz	int
# 	/m/03dywh	int
# 	/m/01987_	int
# 	/m/0b08td	int
# 	/m/06jvx	int
# 	/m/0fq17_h	int
# 	/m/0dyb1	int
# 	/m/01g562	int
# 	/m/02hjn4	int
# 	/m/04lr_4	int
# ...

# %%
df[df['title']=='Jesse Cox']
# Out:
#         title country    subs  videos      views  /m/02hrh1q  /m/07vqnc  \
# 22  Jesse Cox      US  868422    3325  364973435           0          0
#
#     /m/0gyv1hg  /m/02n4hz  /m/03d3jcv    ...      /m/0248b  /m/06l9b  \
# 22           0          0           0    ...             0         0
#
#     /m/026dz5f  /m/07f_7h  /m/01ct6  /m/079m5l  /m/0174k2  /m/043mm3  \
# 22           0          0         0          0          0          0
#
#     /m/05v954  /m/02zw41
# 22          0          0
#
# [1 rows x 7192 columns]

# %%
score.df['title'][22]
# Out:
# u'miniminter'

# %%
score.df['title'][1351]
# Out:
# u'iancoullahan1'

# %%
test = pd.DataFrame(np.array([[1,2,3,4],[2,3,4,5],[3,4,5,6]]))
#test.ix[0] = [5,6,7,8]
#test = test.drop(1)

# %%
test = test.append(pd.DataFrame([[4,5,6,7,8]]), ignore_index=True)

# %%
test
# Out:
#    0  1  2  3   4
# 0  5  6  7  8 NaN
# 1  3  4  5  6 NaN
# 2  4  5  6  7   8

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
scale.fit(test)
s_test = scale.transform(test)

# %%
s_new = scale.transform(pd.DataFrame([[4,5,6,7]]))

# %%
s_new
# Out:
# array([[ 2.44948974,  2.44948974,  2.44948974,  2.44948974]])

# %%
s_test
# Out:
# array([[-1.22474487, -1.22474487, -1.22474487, -1.22474487],
#        [ 0.        ,  0.        ,  0.        ,  0.        ],
#        [ 1.22474487,  1.22474487,  1.22474487,  1.22474487]])

# %%
[1,2,3,4] + [5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
np.where(test[3] == 9)[0]
# Out:
# array([], dtype=int64)

# %%
test.ix[1] = test.ix[0]
test
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  1  2  3  4
# 2  3  4  5  6

# %%
(test.drop(1).values)
# Out:
# array([[1, 2, 3, 4],
#        [3, 4, 5, 6]])

# %%
n = np.random.randn(25)

# %%
n.reshape(5,5)
# Out:
# array([[ 0.70966862,  0.78136625,  0.41529263,  0.11430659, -0.82894223],
#        [-0.3865895 , -1.21856794,  0.76299445, -0.40369745, -0.22021452],
#        [-0.31365968,  0.97784191, -1.29629863, -0.5694082 , -0.87530818],
#        [ 0.27763568, -1.20661682,  0.14286357, -0.12338635, -0.41196362],
#        [ 1.00611166,  1.30415799, -0.60441746,  0.83386977,  1.3846659 ]])

# %%
sort_test = pd.DataFrame(n.reshape(5,5))

# %%
sort_test.drop(3)
# Out:
#           0         1         2         3         4
# 0  0.406321 -0.610866 -1.282410 -1.931874  0.249422
# 1  1.724225 -1.681088 -1.647711  0.254430 -0.693606
# 2 -1.358336 -2.002954 -1.290609 -2.062957  0.878632
# 4  1.355465  0.964731 -0.835276  0.847304  0.588486

# %%
a = {'a': [1,2,3,4,5], 'b':[4,3,2,5,6]}
d = pd.DataFrame(a, columns=['b'])

# %%
d['c'] = n.reshape(5,5)[:,0+2]

# %%
print [1,2,3,4,4,4,4,5].remove(4)
# Out:
# None

# %%
pd.DataFrame(d,
# Out:
#    b
# 0  4
# 1  3
# 2  2
# 3  5
# 4  6
